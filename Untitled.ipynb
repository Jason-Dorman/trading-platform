# %%
from key import key
import pandas as pd
from datetime import datetime
import datetime as dt
import quandl

# %%
stocks = ["WIKI/AAPL", "WIKI/MSFT"]
start = datetime.now() - dt.timedelta(30)
start_date = start.strftime("%Y-%m-%d")
today = datetime.now()
end_date = today.strftime("%Y-%m-%d")

quandl.ApiConfig.api_key = key

for stock in stocks:
    data = quandl.get(stock, start_date='2020=08-12', end_date='2020-09-11')

data
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-17-1ddd6ab26a44> in <module>
#       8
#       9 for stock in stocks:
# ---> 10     data = quandl.get(stock, start_date='2020=08-12', end_date='2020-09-11')
#      11
#      12 data
#
# ~/anaconda3/envs/wolf/lib/python3.8/site-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~/anaconda3/envs/wolf/lib/python3.8/site-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ...

# %%
test = quandl.get("WIKI/AAPL")
test.tail()
# Out:
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
#
#             Adj. Volume
# Date
# 2018-03-21   35247358.0
# 2018-03-22   41051076.0
# 2018-03-23   40248954.0
# ...

# %%
data = quandl.get("WIKI/AAPL", start_date="2020-08-12", end_date="2020-09-10")

# %%
import pandas as pd
import datetime as dt
import yfinance as yf

stocks = ["AAPL", "MSFT"]
start_date = dt.datetime.today() - dt.timedelta(30)
end_date = dt.datetime.today()
cl_price = pd.DataFrame()

for stock in stocks:
    cl_price[stock] = yf.download(stock, start_date, end_date)['Adj Close']
    
cl_price.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   AAPL        MSFT
# 2020-08-12  113.010002  208.685547
# 2020-08-13  115.010002  208.196716
# 2020-08-14  114.907501  208.396240
# 2020-08-17  114.607498  209.772919
# 2020-08-18  115.562500  210.979996
